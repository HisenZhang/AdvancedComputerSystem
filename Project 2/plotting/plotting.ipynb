# %%
import pandas as pd
import seaborn as sns

# %%
f = pd.read_excel("tiled.xlsx")
f["Boost"] *= 100
p = f.pivot("BlockSize","#(N*N)","Boost")

# %%
ax = sns.heatmap(p,square=True, robust=True,annot=True,fmt="+.0f")
for t in ax.texts: 
    t.set_text(t.get_text() + "%")
